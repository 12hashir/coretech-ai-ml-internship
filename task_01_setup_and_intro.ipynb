# %% [markdown]
# **Name:** Hashir Ali
# **Education:** BSCS, Quaid  e Awam University
# **City:** Daharki
# **Skills:** Pyton, C++, HTML
# **Learning Goal:** I want to learn how to build machine learning models and analyze data during this internship.

# %%
print("Hello, Colab!")
a= 10
b= 5
print("Sum of a and b:", a + b)
print("Multiplication of a and b:", a * b)
# Out:
# Hello, Colab!
# Sum of a and b: 15
# Multiplication of a and b: 50
